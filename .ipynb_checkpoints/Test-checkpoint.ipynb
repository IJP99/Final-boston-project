# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor,AdaBoostRegressor, GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("Data/Raw/HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
#Comprobar el tamaño del dataset

df.shape
# Out:
# (506, 14)

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
#Dealing with the null values

df["CRIM"] = df["CRIM"].fillna(df["CRIM"].mean())
df["ZN"] = df["ZN"].fillna(0)
df["INDUS"] = df["INDUS"].fillna(df["INDUS"].mean())
df["AGE"] = df["AGE"].fillna(df["AGE"].mean())
df["LSTAT"] = df["LSTAT"].fillna(df["LSTAT"].mean())

# %%
#dealing the null values of CHAS

null_mask = df['CHAS'].isnull()
num_nulls = null_mask.sum()
num_ones = int(num_nulls * 0.02)
num_zeros = num_nulls - num_ones
replacements = [1] * num_ones + [0] * num_zeros
np.random.shuffle(replacements)
df.loc[null_mask, 'CHAS'] = replacements
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#Create a function to remove the outliers

def identify_outliers(df):
    outliers = pd.DataFrame(index=df.index)
    for column in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        outlier_mask = (df[column] < (Q1 - 1.5 * IQR)) | (df[column] > (Q3 + 1.5 * IQR))
        outliers[column] = outlier_mask
    return outliers

outliers = identify_outliers(df)

#Remove the outliers

df_no_outliers = df[~outliers.any(axis=1)]

# %%
#Percentage of outliers in each column

for k, v in df.items():
    q1 = v.quantile(0.25)
    q3 = v.quantile(0.75)
    iqr = q3 - q1
    v_col = v[(v <= q1 - 1.5 * iqr) | (v >= q3 + 1.5 * iqr)]
    perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
    print("Column %s outliers = %.4f%%" % (k, perc))
# Out:
# Column CRIM outliers = 12.6482%
# Column ZN outliers = 100.0000%
# Column INDUS outliers = 0.0000%
# Column CHAS outliers = 100.0000%
# Column NOX outliers = 0.0000%
# Column RM outliers = 5.9289%
# Column AGE outliers = 0.0000%
# Column DIS outliers = 0.9881%
# Column RAD outliers = 0.0000%
# Column TAX outliers = 0.0000%
# Column PTRATIO outliers = 2.9644%
# Column B outliers = 15.2174%
# Column LSTAT outliers = 2.3715%
# Column MEDV outliers = 7.9051%

# %%
#create a list with the outliers

outliers_list = []

for k, v in df.items():
    q1 = v.quantile(0.25)
    q3 = v.quantile(0.75)
    irq = q3 - q1
    v_col = v[(v <= q1 - 1.5 * irq) | (v >= q3 + 1.5 * irq)]
    perc = np.shape(v_col)[0] * 100.0 / np.shape(df)[0]
    outliers_list.append({'Column': k, 'Outlier_Percentage': perc})

outliers_data = pd.DataFrame(outliers_list)

# create a bar chart to visualize the outliers
plt.figure(figsize=(10, 6))
plt.bar(outliers_data['Column'], outliers_data['Outlier_Percentage'], color='skyblue')
plt.xlabel('Column')
plt.ylabel('Outlier Percentage')
plt.title('Percentage of Outliers in Each Column')
plt.show()

# %%
#Create boxplot of each column in order to have a better look into outliers and the tendency values

fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.boxplot(y=k, data=df, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
#another perspective of the values using histplot with the KDE

fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
axs = axs.flatten()

for index, (k, v) in enumerate(df.items()):
    sns.histplot(v, kde=True, ax=axs[index], label=k)
    axs[index].set_title(k)

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
plt.show()

# %%
#Create a headmap of correlation

plt.figure(figsize=(20, 10))
sns.heatmap(df.corr().abs(),  annot=True)
# Out:
# <Axes: >

# %%
features = df.drop(columns = ["CRIM", "ZN", "CHAS", "RAD", "B", "MEDV", "AGE"])
target = df["MEDV"]

# %%
#TTS

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.20, random_state=30)

# %%
#normalization of the values in the new columns

normalizer = MinMaxScaler()

normalizer.fit(X_train)

X_train_norm = normalizer.transform(X_train)

X_test_norm = normalizer.transform(X_test)

# %%
X_train_norm = pd.DataFrame(X_train_norm, columns = X_train.columns)

X_test_norm = pd.DataFrame(X_test_norm, columns = X_test.columns)

# %%
#training KNN

knn = KNeighborsRegressor(n_neighbors=10)

knn.fit(X_train_norm, y_train)

print(f"The R2 of the model on the TEST set is: {knn.score(X_test_norm, y_test): .2f}")
# Out:
# The R2 of the model on the TEST set is:  0.69

# %%
#linear regression model

lin_reg = LinearRegression()

lin_reg.fit(X_train_norm, y_train)

pred = lin_reg.predict(X_test_norm)

print(f"MAE {mean_absolute_error(pred, y_test): .2f}")
print(f"RMSE, {mean_squared_error(pred, y_test, squared=False): .2f}")
print(f"R2 score, {lin_reg.score(X_test_norm, y_test): .2f}")
# Out:
# MAE  3.45
# RMSE,  4.55
# R2 score,  0.67
# C:\Users\ivanj\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
#bagging and pasting

bagging_reg = BaggingRegressor(DecisionTreeRegressor(max_depth=15),
                               n_estimators=140,
                               max_samples = 300)

bagging_reg.fit(X_train_norm, y_train)

pred = bagging_reg.predict(X_test_norm)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print(F"R2 score, {bagging_reg.score(X_test_norm, y_test): .2F}")
# Out:
# MAE 2.043925245656235
# RMSE 2.719146106976722
# R2 score,  0.88
# C:\Users\ivanj\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
#Random forest method

forest = RandomForestRegressor(n_estimators=140,
                             max_depth=15)

forest.fit(X_train_norm, y_train)

pred = forest.predict(X_test_norm)

print("MAE", mean_absolute_error(pred, y_test))
print("RMSE", mean_squared_error(pred, y_test, squared=False))
print(F"R2 score, {forest.score(X_test_norm, y_test): .3F}")
# Out:
# MAE 2.0882295538449784
# RMSE 2.7767758455287206
# R2 score,  0.879
# C:\Users\ivanj\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Assuming y_test and pred are your true values and predicted values
y_test = np.array(y_test)
pred = np.array(pred)

# Plot the histograms
plt.figure(figsize=(10, 6))

plt.hist(y_test, bins=30, alpha=0.5, label='Actual values')
plt.hist(pred, bins=30, alpha=0.5, label='Predicted values')

# Add title and labels
plt.title('Histogram of Actual vs Predicted Values')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
#grid search

grid = {"max_leaf_nodes": [100, 110, 120, 130, 140, 150],
        "max_depth":[13, 14, 15, 16, 17, 18, 19, 20]}

dt = DecisionTreeRegressor()

model = GridSearchCV(estimator = dt, param_grid = grid, cv=5, verbose=10) # The "cv" option here is used to provide the desired number of folds K.

# %%
model.fit(X_train_norm, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START max_depth=13, max_leaf_nodes=100...........................
# [CV 1/5; 1/48] END max_depth=13, max_leaf_nodes=100;, score=0.648 total time=   0.0s
# [CV 2/5; 1/48] START max_depth=13, max_leaf_nodes=100...........................
# [CV 2/5; 1/48] END max_depth=13, max_leaf_nodes=100;, score=0.739 total time=   0.0s
# [CV 3/5; 1/48] START max_depth=13, max_leaf_nodes=100...........................
# [CV 3/5; 1/48] END max_depth=13, max_leaf_nodes=100;, score=0.855 total time=   0.0s
# [CV 4/5; 1/48] START max_depth=13, max_leaf_nodes=100...........................
# [CV 4/5; 1/48] END max_depth=13, max_leaf_nodes=100;, score=0.747 total time=   0.0s
# [CV 5/5; 1/48] START max_depth=13, max_leaf_nodes=100...........................
# [CV 5/5; 1/48] END max_depth=13, max_leaf_nodes=100;, score=0.458 total time=   0.0s
# [CV 1/5; 2/48] START max_depth=13, max_leaf_nodes=110...........................
# [CV 1/5; 2/48] END max_depth=13, max_leaf_nodes=110;, score=0.618 total time=   0.0s
# [CV 2/5; 2/48] START max_depth=13, max_leaf_nodes=110...........................
# [CV 2/5; 2/48] END max_depth=13, max_leaf_nodes=110;, score=0.741 total time=   0.0s
# [CV 3/5; 2/48] START max_depth=13, max_leaf_nodes=110...........................
# [CV 3/5; 2/48] END max_depth=13, max_leaf_nodes=110;, score=0.858 total time=   0.0s
# [CV 4/5; 2/48] START max_depth=13, max_leaf_nodes=110...........................
# [CV 4/5; 2/48] END max_depth=13, max_leaf_nodes=110;, score=0.743 total time=   0.0s
# [CV 5/5; 2/48] START max_depth=13, max_leaf_nodes=110...........................
# [CV 5/5; 2/48] END max_depth=13, max_leaf_nodes=110;, score=0.454 total time=   0.0s
# [CV 1/5; 3/48] START max_depth=13, max_leaf_nodes=120...........................
# [CV 1/5; 3/48] END max_depth=13, max_leaf_nodes=120;, score=0.618 total time=   0.0s
# [CV 2/5; 3/48] START max_depth=13, max_leaf_nodes=120...........................
# [CV 2/5; 3/48] END max_depth=13, max_leaf_nodes=120;, score=0.773 total time=   0.0s
# [CV 3/5; 3/48] START max_depth=13, max_leaf_nodes=120...........................
# [CV 3/5; 3/48] END max_depth=13, max_leaf_nodes=120;, score=0.841 total time=   0.0s
# [CV 4/5; 3/48] START max_depth=13, max_leaf_nodes=120...........................
# [CV 4/5; 3/48] END max_depth=13, max_leaf_nodes=120;, score=0.823 total time=   0.0s
# [CV 5/5; 3/48] START max_depth=13, max_leaf_nodes=120...........................
# [CV 5/5; 3/48] END max_depth=13, max_leaf_nodes=120;, score=0.492 total time=   0.0s
# [CV 1/5; 4/48] START max_depth=13, max_leaf_nodes=130...........................
# [CV 1/5; 4/48] END max_depth=13, max_leaf_nodes=130;, score=0.610 total time=   0.0s
# [CV 2/5; 4/48] START max_depth=13, max_leaf_nodes=130...........................
# [CV 2/5; 4/48] END max_depth=13, max_leaf_nodes=130;, score=0.721 total time=   0.0s
# [CV 3/5; 4/48] START max_depth=13, max_leaf_nodes=130...........................
# [CV 3/5; 4/48] END max_depth=13, max_leaf_nodes=130;, score=0.866 total time=   0.0s
# [CV 4/5; 4/48] START max_depth=13, max_leaf_nodes=130...........................
# [CV 4/5; 4/48] END max_depth=13, max_leaf_nodes=130;, score=0.757 total time=   0.0s
# [CV 5/5; 4/48] START max_depth=13, max_leaf_nodes=130...........................
# [CV 5/5; 4/48] END max_depth=13, max_leaf_nodes=130;, score=0.461 total time=   0.0s
# [CV 1/5; 5/48] START max_depth=13, max_leaf_nodes=140...........................
# [CV 1/5; 5/48] END max_depth=13, max_leaf_nodes=140;, score=0.607 total time=   0.0s
# [CV 2/5; 5/48] START max_depth=13, max_leaf_nodes=140...........................
# [CV 2/5; 5/48] END max_depth=13, max_leaf_nodes=140;, score=0.709 total time=   0.0s
# [CV 3/5; 5/48] START max_depth=13, max_leaf_nodes=140...........................
# [CV 3/5; 5/48] END max_depth=13, max_leaf_nodes=140;, score=0.858 total time=   0.0s
# [CV 4/5; 5/48] START max_depth=13, max_leaf_nodes=140...........................
# [CV 4/5; 5/48] END max_depth=13, max_leaf_nodes=140;, score=0.746 total time=   0.0s
# [CV 5/5; 5/48] START max_depth=13, max_leaf_nodes=140...........................
# [CV 5/5; 5/48] END max_depth=13, max_leaf_nodes=140;, score=0.450 total time=   0.0s
# [CV 1/5; 6/48] START max_depth=13, max_leaf_nodes=150...........................
# [CV 1/5; 6/48] END max_depth=13, max_leaf_nodes=150;, score=0.688 total time=   0.0s
# [CV 2/5; 6/48] START max_depth=13, max_leaf_nodes=150...........................
# [CV 2/5; 6/48] END max_depth=13, max_leaf_nodes=150;, score=0.780 total time=   0.0s
# [CV 3/5; 6/48] START max_depth=13, max_leaf_nodes=150...........................
# [CV 3/5; 6/48] END max_depth=13, max_leaf_nodes=150;, score=0.850 total time=   0.0s
# [CV 4/5; 6/48] START max_depth=13, max_leaf_nodes=150...........................
# [CV 4/5; 6/48] END max_depth=13, max_leaf_nodes=150;, score=0.777 total time=   0.0s
# [CV 5/5; 6/48] START max_depth=13, max_leaf_nodes=150...........................
# [CV 5/5; 6/48] END max_depth=13, max_leaf_nodes=150;, score=0.449 total time=   0.0s
# [CV 1/5; 7/48] START max_depth=14, max_leaf_nodes=100...........................
# [CV 1/5; 7/48] END max_depth=14, max_leaf_nodes=100;, score=0.645 total time=   0.0s
# [CV 2/5; 7/48] START max_depth=14, max_leaf_nodes=100...........................
# [CV 2/5; 7/48] END max_depth=14, max_leaf_nodes=100;, score=0.782 total time=   0.0s
# [CV 3/5; 7/48] START max_depth=14, max_leaf_nodes=100...........................
# [CV 3/5; 7/48] END max_depth=14, max_leaf_nodes=100;, score=0.854 total time=   0.0s
# [CV 4/5; 7/48] START max_depth=14, max_leaf_nodes=100...........................
# [CV 4/5; 7/48] END max_depth=14, max_leaf_nodes=100;, score=0.750 total time=   0.0s
# [CV 5/5; 7/48] START max_depth=14, max_leaf_nodes=100...........................
# [CV 5/5; 7/48] END max_depth=14, max_leaf_nodes=100;, score=0.459 total time=   0.0s
# [CV 1/5; 8/48] START max_depth=14, max_leaf_nodes=110...........................
# [CV 1/5; 8/48] END max_depth=14, max_leaf_nodes=110;, score=0.703 total time=   0.0s
# [CV 2/5; 8/48] START max_depth=14, max_leaf_nodes=110...........................
# [CV 2/5; 8/48] END max_depth=14, max_leaf_nodes=110;, score=0.773 total time=   0.0s
# [CV 3/5; 8/48] START max_depth=14, max_leaf_nodes=110...........................
# [CV 3/5; 8/48] END max_depth=14, max_leaf_nodes=110;, score=0.860 total time=   0.0s
# [CV 4/5; 8/48] START max_depth=14, max_leaf_nodes=110...........................
# [CV 4/5; 8/48] END max_depth=14, max_leaf_nodes=110;, score=0.766 total time=   0.0s
# [CV 5/5; 8/48] START max_depth=14, max_leaf_nodes=110...........................
# [CV 5/5; 8/48] END max_depth=14, max_leaf_nodes=110;, score=0.449 total time=   0.0s
# [CV 1/5; 9/48] START max_depth=14, max_leaf_nodes=120...........................
# [CV 1/5; 9/48] END max_depth=14, max_leaf_nodes=120;, score=0.622 total time=   0.0s
# [CV 2/5; 9/48] START max_depth=14, max_leaf_nodes=120...........................
# [CV 2/5; 9/48] END max_depth=14, max_leaf_nodes=120;, score=0.710 total time=   0.0s
# [CV 3/5; 9/48] START max_depth=14, max_leaf_nodes=120...........................
# [CV 3/5; 9/48] END max_depth=14, max_leaf_nodes=120;, score=0.851 total time=   0.0s
# [CV 4/5; 9/48] START max_depth=14, max_leaf_nodes=120...........................
# [CV 4/5; 9/48] END max_depth=14, max_leaf_nodes=120;, score=0.806 total time=   0.0s
# [CV 5/5; 9/48] START max_depth=14, max_leaf_nodes=120...........................
# [CV 5/5; 9/48] END max_depth=14, max_leaf_nodes=120;, score=0.485 total time=   0.0s
# [CV 1/5; 10/48] START max_depth=14, max_leaf_nodes=130..........................
# [CV 1/5; 10/48] END max_depth=14, max_leaf_nodes=130;, score=0.616 total time=   0.0s
# [CV 2/5; 10/48] START max_depth=14, max_leaf_nodes=130..........................
# [CV 2/5; 10/48] END max_depth=14, max_leaf_nodes=130;, score=0.700 total time=   0.0s
# [CV 3/5; 10/48] START max_depth=14, max_leaf_nodes=130..........................
# [CV 3/5; 10/48] END max_depth=14, max_leaf_nodes=130;, score=0.864 total time=   0.0s
# [CV 4/5; 10/48] START max_depth=14, max_leaf_nodes=130..........................
# [CV 4/5; 10/48] END max_depth=14, max_leaf_nodes=130;, score=0.745 total time=   0.0s
# [CV 5/5; 10/48] START max_depth=14, max_leaf_nodes=130..........................
# [CV 5/5; 10/48] END max_depth=14, max_leaf_nodes=130;, score=0.490 total time=   0.0s
# [CV 1/5; 11/48] START max_depth=14, max_leaf_nodes=140..........................
# [CV 1/5; 11/48] END max_depth=14, max_leaf_nodes=140;, score=0.670 total time=   0.0s
# [CV 2/5; 11/48] START max_depth=14, max_leaf_nodes=140..........................
# [CV 2/5; 11/48] END max_depth=14, max_leaf_nodes=140;, score=0.784 total time=   0.0s
# [CV 3/5; 11/48] START max_depth=14, max_leaf_nodes=140..........................
# [CV 3/5; 11/48] END max_depth=14, max_leaf_nodes=140;, score=0.846 total time=   0.0s
# [CV 4/5; 11/48] START max_depth=14, max_leaf_nodes=140..........................
# [CV 4/5; 11/48] END max_depth=14, max_leaf_nodes=140;, score=0.806 total time=   0.0s
# [CV 5/5; 11/48] START max_depth=14, max_leaf_nodes=140..........................
# [CV 5/5; 11/48] END max_depth=14, max_leaf_nodes=140;, score=0.489 total time=   0.0s
# [CV 1/5; 12/48] START max_depth=14, max_leaf_nodes=150..........................
# [CV 1/5; 12/48] END max_depth=14, max_leaf_nodes=150;, score=0.609 total time=   0.0s
# [CV 2/5; 12/48] START max_depth=14, max_leaf_nodes=150..........................
# [CV 2/5; 12/48] END max_depth=14, max_leaf_nodes=150;, score=0.784 total time=   0.0s
# [CV 3/5; 12/48] START max_depth=14, max_leaf_nodes=150..........................
# [CV 3/5; 12/48] END max_depth=14, max_leaf_nodes=150;, score=0.864 total time=   0.0s
# [CV 4/5; 12/48] START max_depth=14, max_leaf_nodes=150..........................
# [CV 4/5; 12/48] END max_depth=14, max_leaf_nodes=150;, score=0.739 total time=   0.0s
# [CV 5/5; 12/48] START max_depth=14, max_leaf_nodes=150..........................
# [CV 5/5; 12/48] END max_depth=14, max_leaf_nodes=150;, score=0.472 total time=   0.0s
# [CV 1/5; 13/48] START max_depth=15, max_leaf_nodes=100..........................
# [CV 1/5; 13/48] END max_depth=15, max_leaf_nodes=100;, score=0.622 total time=   0.0s
# [CV 2/5; 13/48] START max_depth=15, max_leaf_nodes=100..........................
# [CV 2/5; 13/48] END max_depth=15, max_leaf_nodes=100;, score=0.776 total time=   0.0s
# [CV 3/5; 13/48] START max_depth=15, max_leaf_nodes=100..........................
# [CV 3/5; 13/48] END max_depth=15, max_leaf_nodes=100;, score=0.836 total time=   0.0s
# [CV 4/5; 13/48] START max_depth=15, max_leaf_nodes=100..........................
# [CV 4/5; 13/48] END max_depth=15, max_leaf_nodes=100;, score=0.798 total time=   0.0s
# [CV 5/5; 13/48] START max_depth=15, max_leaf_nodes=100..........................
# [CV 5/5; 13/48] END max_depth=15, max_leaf_nodes=100;, score=0.460 total time=   0.0s
# [CV 1/5; 14/48] START max_depth=15, max_leaf_nodes=110..........................
# [CV 1/5; 14/48] END max_depth=15, max_leaf_nodes=110;, score=0.678 total time=   0.0s
# [CV 2/5; 14/48] START max_depth=15, max_leaf_nodes=110..........................
# [CV 2/5; 14/48] END max_depth=15, max_leaf_nodes=110;, score=0.759 total time=   0.0s
# [CV 3/5; 14/48] START max_depth=15, max_leaf_nodes=110..........................
# [CV 3/5; 14/48] END max_depth=15, max_leaf_nodes=110;, score=0.846 total time=   0.0s
# [CV 4/5; 14/48] START max_depth=15, max_leaf_nodes=110..........................
# [CV 4/5; 14/48] END max_depth=15, max_leaf_nodes=110;, score=0.763 total time=   0.0s
# [CV 5/5; 14/48] START max_depth=15, max_leaf_nodes=110..........................
# [CV 5/5; 14/48] END max_depth=15, max_leaf_nodes=110;, score=0.488 total time=   0.0s
# [CV 1/5; 15/48] START max_depth=15, max_leaf_nodes=120..........................
# [CV 1/5; 15/48] END max_depth=15, max_leaf_nodes=120;, score=0.641 total time=   0.0s
# [CV 2/5; 15/48] START max_depth=15, max_leaf_nodes=120..........................
# [CV 2/5; 15/48] END max_depth=15, max_leaf_nodes=120;, score=0.777 total time=   0.0s
# [CV 3/5; 15/48] START max_depth=15, max_leaf_nodes=120..........................
# [CV 3/5; 15/48] END max_depth=15, max_leaf_nodes=120;, score=0.856 total time=   0.0s
# [CV 4/5; 15/48] START max_depth=15, max_leaf_nodes=120..........................
# [CV 4/5; 15/48] END max_depth=15, max_leaf_nodes=120;, score=0.756 total time=   0.0s
# [CV 5/5; 15/48] START max_depth=15, max_leaf_nodes=120..........................
# [CV 5/5; 15/48] END max_depth=15, max_leaf_nodes=120;, score=0.464 total time=   0.0s
# [CV 1/5; 16/48] START max_depth=15, max_leaf_nodes=130..........................
# [CV 1/5; 16/48] END max_depth=15, max_leaf_nodes=130;, score=0.644 total time=   0.0s
# [CV 2/5; 16/48] START max_depth=15, max_leaf_nodes=130..........................
# [CV 2/5; 16/48] END max_depth=15, max_leaf_nodes=130;, score=0.763 total time=   0.0s
# [CV 3/5; 16/48] START max_depth=15, max_leaf_nodes=130..........................
# [CV 3/5; 16/48] END max_depth=15, max_leaf_nodes=130;, score=0.858 total time=   0.0s
# [CV 4/5; 16/48] START max_depth=15, max_leaf_nodes=130..........................
# [CV 4/5; 16/48] END max_depth=15, max_leaf_nodes=130;, score=0.746 total time=   0.0s
# [CV 5/5; 16/48] START max_depth=15, max_leaf_nodes=130..........................
# [CV 5/5; 16/48] END max_depth=15, max_leaf_nodes=130;, score=0.458 total time=   0.0s
# [CV 1/5; 17/48] START max_depth=15, max_leaf_nodes=140..........................
# [CV 1/5; 17/48] END max_depth=15, max_leaf_nodes=140;, score=0.678 total time=   0.0s
# [CV 2/5; 17/48] START max_depth=15, max_leaf_nodes=140..........................
# [CV 2/5; 17/48] END max_depth=15, max_leaf_nodes=140;, score=0.750 total time=   0.0s
# [CV 3/5; 17/48] START max_depth=15, max_leaf_nodes=140..........................
# [CV 3/5; 17/48] END max_depth=15, max_leaf_nodes=140;, score=0.854 total time=   0.0s
# [CV 4/5; 17/48] START max_depth=15, max_leaf_nodes=140..........................
# [CV 4/5; 17/48] END max_depth=15, max_leaf_nodes=140;, score=0.757 total time=   0.0s
# [CV 5/5; 17/48] START max_depth=15, max_leaf_nodes=140..........................
# [CV 5/5; 17/48] END max_depth=15, max_leaf_nodes=140;, score=0.451 total time=   0.0s
# [CV 1/5; 18/48] START max_depth=15, max_leaf_nodes=150..........................
# [CV 1/5; 18/48] END max_depth=15, max_leaf_nodes=150;, score=0.672 total time=   0.0s
# [CV 2/5; 18/48] START max_depth=15, max_leaf_nodes=150..........................
# [CV 2/5; 18/48] END max_depth=15, max_leaf_nodes=150;, score=0.742 total time=   0.0s
# [CV 3/5; 18/48] START max_depth=15, max_leaf_nodes=150..........................
# [CV 3/5; 18/48] END max_depth=15, max_leaf_nodes=150;, score=0.859 total time=   0.0s
# [CV 4/5; 18/48] START max_depth=15, max_leaf_nodes=150..........................
# [CV 4/5; 18/48] END max_depth=15, max_leaf_nodes=150;, score=0.782 total time=   0.0s
# [CV 5/5; 18/48] START max_depth=15, max_leaf_nodes=150..........................
# [CV 5/5; 18/48] END max_depth=15, max_leaf_nodes=150;, score=0.452 total time=   0.0s
# [CV 1/5; 19/48] START max_depth=16, max_leaf_nodes=100..........................
# [CV 1/5; 19/48] END max_depth=16, max_leaf_nodes=100;, score=0.625 total time=   0.0s
# [CV 2/5; 19/48] START max_depth=16, max_leaf_nodes=100..........................
# [CV 2/5; 19/48] END max_depth=16, max_leaf_nodes=100;, score=0.756 total time=   0.0s
# [CV 3/5; 19/48] START max_depth=16, max_leaf_nodes=100..........................
# [CV 3/5; 19/48] END max_depth=16, max_leaf_nodes=100;, score=0.863 total time=   0.0s
# [CV 4/5; 19/48] START max_depth=16, max_leaf_nodes=100..........................
# [CV 4/5; 19/48] END max_depth=16, max_leaf_nodes=100;, score=0.801 total time=   0.0s
# [CV 5/5; 19/48] START max_depth=16, max_leaf_nodes=100..........................
# [CV 5/5; 19/48] END max_depth=16, max_leaf_nodes=100;, score=0.463 total time=   0.0s
# [CV 1/5; 20/48] START max_depth=16, max_leaf_nodes=110..........................
# [CV 1/5; 20/48] END max_depth=16, max_leaf_nodes=110;, score=0.641 total time=   0.0s
# [CV 2/5; 20/48] START max_depth=16, max_leaf_nodes=110..........................
# [CV 2/5; 20/48] END max_depth=16, max_leaf_nodes=110;, score=0.729 total time=   0.0s
# [CV 3/5; 20/48] START max_depth=16, max_leaf_nodes=110..........................
# [CV 3/5; 20/48] END max_depth=16, max_leaf_nodes=110;, score=0.862 total time=   0.0s
# [CV 4/5; 20/48] START max_depth=16, max_leaf_nodes=110..........................
# [CV 4/5; 20/48] END max_depth=16, max_leaf_nodes=110;, score=0.807 total time=   0.0s
# [CV 5/5; 20/48] START max_depth=16, max_leaf_nodes=110..........................
# [CV 5/5; 20/48] END max_depth=16, max_leaf_nodes=110;, score=0.459 total time=   0.0s
# [CV 1/5; 21/48] START max_depth=16, max_leaf_nodes=120..........................
# [CV 1/5; 21/48] END max_depth=16, max_leaf_nodes=120;, score=0.610 total time=   0.0s
# [CV 2/5; 21/48] START max_depth=16, max_leaf_nodes=120..........................
# [CV 2/5; 21/48] END max_depth=16, max_leaf_nodes=120;, score=0.733 total time=   0.0s
# [CV 3/5; 21/48] START max_depth=16, max_leaf_nodes=120..........................
# [CV 3/5; 21/48] END max_depth=16, max_leaf_nodes=120;, score=0.863 total time=   0.0s
# [CV 4/5; 21/48] START max_depth=16, max_leaf_nodes=120..........................
# [CV 4/5; 21/48] END max_depth=16, max_leaf_nodes=120;, score=0.764 total time=   0.0s
# [CV 5/5; 21/48] START max_depth=16, max_leaf_nodes=120..........................
# [CV 5/5; 21/48] END max_depth=16, max_leaf_nodes=120;, score=0.492 total time=   0.0s
# [CV 1/5; 22/48] START max_depth=16, max_leaf_nodes=130..........................
# [CV 1/5; 22/48] END max_depth=16, max_leaf_nodes=130;, score=0.614 total time=   0.0s
# [CV 2/5; 22/48] START max_depth=16, max_leaf_nodes=130..........................
# [CV 2/5; 22/48] END max_depth=16, max_leaf_nodes=130;, score=0.714 total time=   0.0s
# [CV 3/5; 22/48] START max_depth=16, max_leaf_nodes=130..........................
# [CV 3/5; 22/48] END max_depth=16, max_leaf_nodes=130;, score=0.861 total time=   0.0s
# [CV 4/5; 22/48] START max_depth=16, max_leaf_nodes=130..........................
# [CV 4/5; 22/48] END max_depth=16, max_leaf_nodes=130;, score=0.737 total time=   0.0s
# [CV 5/5; 22/48] START max_depth=16, max_leaf_nodes=130..........................
# [CV 5/5; 22/48] END max_depth=16, max_leaf_nodes=130;, score=0.478 total time=   0.0s
# [CV 1/5; 23/48] START max_depth=16, max_leaf_nodes=140..........................
# [CV 1/5; 23/48] END max_depth=16, max_leaf_nodes=140;, score=0.620 total time=   0.0s
# [CV 2/5; 23/48] START max_depth=16, max_leaf_nodes=140..........................
# [CV 2/5; 23/48] END max_depth=16, max_leaf_nodes=140;, score=0.736 total time=   0.0s
# [CV 3/5; 23/48] START max_depth=16, max_leaf_nodes=140..........................
# [CV 3/5; 23/48] END max_depth=16, max_leaf_nodes=140;, score=0.855 total time=   0.0s
# [CV 4/5; 23/48] START max_depth=16, max_leaf_nodes=140..........................
# [CV 4/5; 23/48] END max_depth=16, max_leaf_nodes=140;, score=0.722 total time=   0.0s
# [CV 5/5; 23/48] START max_depth=16, max_leaf_nodes=140..........................
# [CV 5/5; 23/48] END max_depth=16, max_leaf_nodes=140;, score=0.441 total time=   0.0s
# [CV 1/5; 24/48] START max_depth=16, max_leaf_nodes=150..........................
# [CV 1/5; 24/48] END max_depth=16, max_leaf_nodes=150;, score=0.649 total time=   0.0s
# [CV 2/5; 24/48] START max_depth=16, max_leaf_nodes=150..........................
# [CV 2/5; 24/48] END max_depth=16, max_leaf_nodes=150;, score=0.762 total time=   0.0s
# [CV 3/5; 24/48] START max_depth=16, max_leaf_nodes=150..........................
# [CV 3/5; 24/48] END max_depth=16, max_leaf_nodes=150;, score=0.856 total time=   0.0s
# [CV 4/5; 24/48] START max_depth=16, max_leaf_nodes=150..........................
# [CV 4/5; 24/48] END max_depth=16, max_leaf_nodes=150;, score=0.756 total time=   0.0s
# [CV 5/5; 24/48] START max_depth=16, max_leaf_nodes=150..........................
# [CV 5/5; 24/48] END max_depth=16, max_leaf_nodes=150;, score=0.471 total time=   0.0s
# [CV 1/5; 25/48] START max_depth=17, max_leaf_nodes=100..........................
# [CV 1/5; 25/48] END max_depth=17, max_leaf_nodes=100;, score=0.711 total time=   0.0s
# [CV 2/5; 25/48] START max_depth=17, max_leaf_nodes=100..........................
# [CV 2/5; 25/48] END max_depth=17, max_leaf_nodes=100;, score=0.754 total time=   0.0s
# [CV 3/5; 25/48] START max_depth=17, max_leaf_nodes=100..........................
# [CV 3/5; 25/48] END max_depth=17, max_leaf_nodes=100;, score=0.841 total time=   0.0s
# [CV 4/5; 25/48] START max_depth=17, max_leaf_nodes=100..........................
# [CV 4/5; 25/48] END max_depth=17, max_leaf_nodes=100;, score=0.759 total time=   0.0s
# [CV 5/5; 25/48] START max_depth=17, max_leaf_nodes=100..........................
# [CV 5/5; 25/48] END max_depth=17, max_leaf_nodes=100;, score=0.464 total time=   0.0s
# [CV 1/5; 26/48] START max_depth=17, max_leaf_nodes=110..........................
# [CV 1/5; 26/48] END max_depth=17, max_leaf_nodes=110;, score=0.644 total time=   0.0s
# [CV 2/5; 26/48] START max_depth=17, max_leaf_nodes=110..........................
# [CV 2/5; 26/48] END max_depth=17, max_leaf_nodes=110;, score=0.786 total time=   0.0s
# [CV 3/5; 26/48] START max_depth=17, max_leaf_nodes=110..........................
# [CV 3/5; 26/48] END max_depth=17, max_leaf_nodes=110;, score=0.852 total time=   0.0s
# [CV 4/5; 26/48] START max_depth=17, max_leaf_nodes=110..........................
# [CV 4/5; 26/48] END max_depth=17, max_leaf_nodes=110;, score=0.767 total time=   0.0s
# [CV 5/5; 26/48] START max_depth=17, max_leaf_nodes=110..........................
# [CV 5/5; 26/48] END max_depth=17, max_leaf_nodes=110;, score=0.465 total time=   0.0s
# [CV 1/5; 27/48] START max_depth=17, max_leaf_nodes=120..........................
# [CV 1/5; 27/48] END max_depth=17, max_leaf_nodes=120;, score=0.678 total time=   0.0s
# [CV 2/5; 27/48] START max_depth=17, max_leaf_nodes=120..........................
# [CV 2/5; 27/48] END max_depth=17, max_leaf_nodes=120;, score=0.762 total time=   0.0s
# [CV 3/5; 27/48] START max_depth=17, max_leaf_nodes=120..........................
# [CV 3/5; 27/48] END max_depth=17, max_leaf_nodes=120;, score=0.857 total time=   0.0s
# [CV 4/5; 27/48] START max_depth=17, max_leaf_nodes=120..........................
# [CV 4/5; 27/48] END max_depth=17, max_leaf_nodes=120;, score=0.715 total time=   0.0s
# [CV 5/5; 27/48] START max_depth=17, max_leaf_nodes=120..........................
# [CV 5/5; 27/48] END max_depth=17, max_leaf_nodes=120;, score=0.457 total time=   0.0s
# [CV 1/5; 28/48] START max_depth=17, max_leaf_nodes=130..........................
# [CV 1/5; 28/48] END max_depth=17, max_leaf_nodes=130;, score=0.683 total time=   0.0s
# [CV 2/5; 28/48] START max_depth=17, max_leaf_nodes=130..........................
# [CV 2/5; 28/48] END max_depth=17, max_leaf_nodes=130;, score=0.770 total time=   0.0s
# [CV 3/5; 28/48] START max_depth=17, max_leaf_nodes=130..........................
# [CV 3/5; 28/48] END max_depth=17, max_leaf_nodes=130;, score=0.867 total time=   0.0s
# [CV 4/5; 28/48] START max_depth=17, max_leaf_nodes=130..........................
# [CV 4/5; 28/48] END max_depth=17, max_leaf_nodes=130;, score=0.791 total time=   0.0s
# [CV 5/5; 28/48] START max_depth=17, max_leaf_nodes=130..........................
# [CV 5/5; 28/48] END max_depth=17, max_leaf_nodes=130;, score=0.456 total time=   0.0s
# [CV 1/5; 29/48] START max_depth=17, max_leaf_nodes=140..........................
# [CV 1/5; 29/48] END max_depth=17, max_leaf_nodes=140;, score=0.612 total time=   0.0s
# [CV 2/5; 29/48] START max_depth=17, max_leaf_nodes=140..........................
# [CV 2/5; 29/48] END max_depth=17, max_leaf_nodes=140;, score=0.780 total time=   0.0s
# [CV 3/5; 29/48] START max_depth=17, max_leaf_nodes=140..........................
# [CV 3/5; 29/48] END max_depth=17, max_leaf_nodes=140;, score=0.862 total time=   0.0s
# [CV 4/5; 29/48] START max_depth=17, max_leaf_nodes=140..........................
# [CV 4/5; 29/48] END max_depth=17, max_leaf_nodes=140;, score=0.753 total time=   0.0s
# [CV 5/5; 29/48] START max_depth=17, max_leaf_nodes=140..........................
# [CV 5/5; 29/48] END max_depth=17, max_leaf_nodes=140;, score=0.457 total time=   0.0s
# [CV 1/5; 30/48] START max_depth=17, max_leaf_nodes=150..........................
# [CV 1/5; 30/48] END max_depth=17, max_leaf_nodes=150;, score=0.647 total time=   0.0s
# [CV 2/5; 30/48] START max_depth=17, max_leaf_nodes=150..........................
# [CV 2/5; 30/48] END max_depth=17, max_leaf_nodes=150;, score=0.753 total time=   0.0s
# [CV 3/5; 30/48] START max_depth=17, max_leaf_nodes=150..........................
# [CV 3/5; 30/48] END max_depth=17, max_leaf_nodes=150;, score=0.861 total time=   0.0s
# [CV 4/5; 30/48] START max_depth=17, max_leaf_nodes=150..........................
# [CV 4/5; 30/48] END max_depth=17, max_leaf_nodes=150;, score=0.786 total time=   0.0s
# [CV 5/5; 30/48] START max_depth=17, max_leaf_nodes=150..........................
# [CV 5/5; 30/48] END max_depth=17, max_leaf_nodes=150;, score=0.456 total time=   0.0s
# [CV 1/5; 31/48] START max_depth=18, max_leaf_nodes=100..........................
# [CV 1/5; 31/48] END max_depth=18, max_leaf_nodes=100;, score=0.623 total time=   0.0s
# [CV 2/5; 31/48] START max_depth=18, max_leaf_nodes=100..........................
# [CV 2/5; 31/48] END max_depth=18, max_leaf_nodes=100;, score=0.778 total time=   0.0s
# [CV 3/5; 31/48] START max_depth=18, max_leaf_nodes=100..........................
# [CV 3/5; 31/48] END max_depth=18, max_leaf_nodes=100;, score=0.856 total time=   0.0s
# [CV 4/5; 31/48] START max_depth=18, max_leaf_nodes=100..........................
# [CV 4/5; 31/48] END max_depth=18, max_leaf_nodes=100;, score=0.752 total time=   0.0s
# [CV 5/5; 31/48] START max_depth=18, max_leaf_nodes=100..........................
# [CV 5/5; 31/48] END max_depth=18, max_leaf_nodes=100;, score=0.492 total time=   0.0s
# [CV 1/5; 32/48] START max_depth=18, max_leaf_nodes=110..........................
# [CV 1/5; 32/48] END max_depth=18, max_leaf_nodes=110;, score=0.680 total time=   0.0s
# [CV 2/5; 32/48] START max_depth=18, max_leaf_nodes=110..........................
# [CV 2/5; 32/48] END max_depth=18, max_leaf_nodes=110;, score=0.769 total time=   0.0s
# [CV 3/5; 32/48] START max_depth=18, max_leaf_nodes=110..........................
# [CV 3/5; 32/48] END max_depth=18, max_leaf_nodes=110;, score=0.852 total time=   0.0s
# [CV 4/5; 32/48] START max_depth=18, max_leaf_nodes=110..........................
# [CV 4/5; 32/48] END max_depth=18, max_leaf_nodes=110;, score=0.776 total time=   0.0s
# [CV 5/5; 32/48] START max_depth=18, max_leaf_nodes=110..........................
# [CV 5/5; 32/48] END max_depth=18, max_leaf_nodes=110;, score=0.492 total time=   0.0s
# [CV 1/5; 33/48] START max_depth=18, max_leaf_nodes=120..........................
# [CV 1/5; 33/48] END max_depth=18, max_leaf_nodes=120;, score=0.674 total time=   0.0s
# [CV 2/5; 33/48] START max_depth=18, max_leaf_nodes=120..........................
# [CV 2/5; 33/48] END max_depth=18, max_leaf_nodes=120;, score=0.742 total time=   0.0s
# [CV 3/5; 33/48] START max_depth=18, max_leaf_nodes=120..........................
# [CV 3/5; 33/48] END max_depth=18, max_leaf_nodes=120;, score=0.853 total time=   0.0s
# [CV 4/5; 33/48] START max_depth=18, max_leaf_nodes=120..........................
# [CV 4/5; 33/48] END max_depth=18, max_leaf_nodes=120;, score=0.765 total time=   0.0s
# [CV 5/5; 33/48] START max_depth=18, max_leaf_nodes=120..........................
# [CV 5/5; 33/48] END max_depth=18, max_leaf_nodes=120;, score=0.445 total time=   0.0s
# [CV 1/5; 34/48] START max_depth=18, max_leaf_nodes=130..........................
# [CV 1/5; 34/48] END max_depth=18, max_leaf_nodes=130;, score=0.709 total time=   0.0s
# [CV 2/5; 34/48] START max_depth=18, max_leaf_nodes=130..........................
# [CV 2/5; 34/48] END max_depth=18, max_leaf_nodes=130;, score=0.776 total time=   0.0s
# [CV 3/5; 34/48] START max_depth=18, max_leaf_nodes=130..........................
# [CV 3/5; 34/48] END max_depth=18, max_leaf_nodes=130;, score=0.860 total time=   0.0s
# [CV 4/5; 34/48] START max_depth=18, max_leaf_nodes=130..........................
# [CV 4/5; 34/48] END max_depth=18, max_leaf_nodes=130;, score=0.770 total time=   0.0s
# [CV 5/5; 34/48] START max_depth=18, max_leaf_nodes=130..........................
# [CV 5/5; 34/48] END max_depth=18, max_leaf_nodes=130;, score=0.487 total time=   0.0s
# [CV 1/5; 35/48] START max_depth=18, max_leaf_nodes=140..........................
# [CV 1/5; 35/48] END max_depth=18, max_leaf_nodes=140;, score=0.709 total time=   0.0s
# [CV 2/5; 35/48] START max_depth=18, max_leaf_nodes=140..........................
# [CV 2/5; 35/48] END max_depth=18, max_leaf_nodes=140;, score=0.795 total time=   0.0s
# [CV 3/5; 35/48] START max_depth=18, max_leaf_nodes=140..........................
# [CV 3/5; 35/48] END max_depth=18, max_leaf_nodes=140;, score=0.861 total time=   0.0s
# [CV 4/5; 35/48] START max_depth=18, max_leaf_nodes=140..........................
# [CV 4/5; 35/48] END max_depth=18, max_leaf_nodes=140;, score=0.767 total time=   0.0s
# [CV 5/5; 35/48] START max_depth=18, max_leaf_nodes=140..........................
# [CV 5/5; 35/48] END max_depth=18, max_leaf_nodes=140;, score=0.475 total time=   0.0s
# [CV 1/5; 36/48] START max_depth=18, max_leaf_nodes=150..........................
# [CV 1/5; 36/48] END max_depth=18, max_leaf_nodes=150;, score=0.616 total time=   0.0s
# [CV 2/5; 36/48] START max_depth=18, max_leaf_nodes=150..........................
# [CV 2/5; 36/48] END max_depth=18, max_leaf_nodes=150;, score=0.780 total time=   0.0s
# [CV 3/5; 36/48] START max_depth=18, max_leaf_nodes=150..........................
# [CV 3/5; 36/48] END max_depth=18, max_leaf_nodes=150;, score=0.862 total time=   0.0s
# [CV 4/5; 36/48] START max_depth=18, max_leaf_nodes=150..........................
# [CV 4/5; 36/48] END max_depth=18, max_leaf_nodes=150;, score=0.745 total time=   0.0s
# [CV 5/5; 36/48] START max_depth=18, max_leaf_nodes=150..........................
# [CV 5/5; 36/48] END max_depth=18, max_leaf_nodes=150;, score=0.449 total time=   0.0s
# [CV 1/5; 37/48] START max_depth=19, max_leaf_nodes=100..........................
# [CV 1/5; 37/48] END max_depth=19, max_leaf_nodes=100;, score=0.685 total time=   0.0s
# [CV 2/5; 37/48] START max_depth=19, max_leaf_nodes=100..........................
# [CV 2/5; 37/48] END max_depth=19, max_leaf_nodes=100;, score=0.730 total time=   0.0s
# [CV 3/5; 37/48] START max_depth=19, max_leaf_nodes=100..........................
# [CV 3/5; 37/48] END max_depth=19, max_leaf_nodes=100;, score=0.852 total time=   0.0s
# [CV 4/5; 37/48] START max_depth=19, max_leaf_nodes=100..........................
# [CV 4/5; 37/48] END max_depth=19, max_leaf_nodes=100;, score=0.788 total time=   0.0s
# [CV 5/5; 37/48] START max_depth=19, max_leaf_nodes=100..........................
# [CV 5/5; 37/48] END max_depth=19, max_leaf_nodes=100;, score=0.461 total time=   0.0s
# [CV 1/5; 38/48] START max_depth=19, max_leaf_nodes=110..........................
# [CV 1/5; 38/48] END max_depth=19, max_leaf_nodes=110;, score=0.705 total time=   0.0s
# [CV 2/5; 38/48] START max_depth=19, max_leaf_nodes=110..........................
# [CV 2/5; 38/48] END max_depth=19, max_leaf_nodes=110;, score=0.751 total time=   0.0s
# [CV 3/5; 38/48] START max_depth=19, max_leaf_nodes=110..........................
# [CV 3/5; 38/48] END max_depth=19, max_leaf_nodes=110;, score=0.845 total time=   0.0s
# [CV 4/5; 38/48] START max_depth=19, max_leaf_nodes=110..........................
# [CV 4/5; 38/48] END max_depth=19, max_leaf_nodes=110;, score=0.742 total time=   0.0s
# [CV 5/5; 38/48] START max_depth=19, max_leaf_nodes=110..........................
# [CV 5/5; 38/48] END max_depth=19, max_leaf_nodes=110;, score=0.493 total time=   0.0s
# [CV 1/5; 39/48] START max_depth=19, max_leaf_nodes=120..........................
# [CV 1/5; 39/48] END max_depth=19, max_leaf_nodes=120;, score=0.636 total time=   0.0s
# [CV 2/5; 39/48] START max_depth=19, max_leaf_nodes=120..........................
# [CV 2/5; 39/48] END max_depth=19, max_leaf_nodes=120;, score=0.716 total time=   0.0s
# [CV 3/5; 39/48] START max_depth=19, max_leaf_nodes=120..........................
# [CV 3/5; 39/48] END max_depth=19, max_leaf_nodes=120;, score=0.859 total time=   0.0s
# [CV 4/5; 39/48] START max_depth=19, max_leaf_nodes=120..........................
# [CV 4/5; 39/48] END max_depth=19, max_leaf_nodes=120;, score=0.805 total time=   0.0s
# [CV 5/5; 39/48] START max_depth=19, max_leaf_nodes=120..........................
# [CV 5/5; 39/48] END max_depth=19, max_leaf_nodes=120;, score=0.456 total time=   0.0s
# [CV 1/5; 40/48] START max_depth=19, max_leaf_nodes=130..........................
# [CV 1/5; 40/48] END max_depth=19, max_leaf_nodes=130;, score=0.612 total time=   0.0s
# [CV 2/5; 40/48] START max_depth=19, max_leaf_nodes=130..........................
# [CV 2/5; 40/48] END max_depth=19, max_leaf_nodes=130;, score=0.717 total time=   0.0s
# [CV 3/5; 40/48] START max_depth=19, max_leaf_nodes=130..........................
# [CV 3/5; 40/48] END max_depth=19, max_leaf_nodes=130;, score=0.850 total time=   0.0s
# [CV 4/5; 40/48] START max_depth=19, max_leaf_nodes=130..........................
# [CV 4/5; 40/48] END max_depth=19, max_leaf_nodes=130;, score=0.779 total time=   0.0s
# [CV 5/5; 40/48] START max_depth=19, max_leaf_nodes=130..........................
# [CV 5/5; 40/48] END max_depth=19, max_leaf_nodes=130;, score=0.459 total time=   0.0s
# [CV 1/5; 41/48] START max_depth=19, max_leaf_nodes=140..........................
# [CV 1/5; 41/48] END max_depth=19, max_leaf_nodes=140;, score=0.627 total time=   0.0s
# [CV 2/5; 41/48] START max_depth=19, max_leaf_nodes=140..........................
# [CV 2/5; 41/48] END max_depth=19, max_leaf_nodes=140;, score=0.729 total time=   0.0s
# [CV 3/5; 41/48] START max_depth=19, max_leaf_nodes=140..........................
# [CV 3/5; 41/48] END max_depth=19, max_leaf_nodes=140;, score=0.871 total time=   0.0s
# [CV 4/5; 41/48] START max_depth=19, max_leaf_nodes=140..........................
# [CV 4/5; 41/48] END max_depth=19, max_leaf_nodes=140;, score=0.739 total time=   0.0s
# [CV 5/5; 41/48] START max_depth=19, max_leaf_nodes=140..........................
# [CV 5/5; 41/48] END max_depth=19, max_leaf_nodes=140;, score=0.475 total time=   0.0s
# [CV 1/5; 42/48] START max_depth=19, max_leaf_nodes=150..........................
# [CV 1/5; 42/48] END max_depth=19, max_leaf_nodes=150;, score=0.647 total time=   0.0s
# [CV 2/5; 42/48] START max_depth=19, max_leaf_nodes=150..........................
# [CV 2/5; 42/48] END max_depth=19, max_leaf_nodes=150;, score=0.745 total time=   0.0s
# [CV 3/5; 42/48] START max_depth=19, max_leaf_nodes=150..........................
# [CV 3/5; 42/48] END max_depth=19, max_leaf_nodes=150;, score=0.870 total time=   0.0s
# [CV 4/5; 42/48] START max_depth=19, max_leaf_nodes=150..........................
# [CV 4/5; 42/48] END max_depth=19, max_leaf_nodes=150;, score=0.766 total time=   0.0s
# [CV 5/5; 42/48] START max_depth=19, max_leaf_nodes=150..........................
# [CV 5/5; 42/48] END max_depth=19, max_leaf_nodes=150;, score=0.490 total time=   0.0s
# [CV 1/5; 43/48] START max_depth=20, max_leaf_nodes=100..........................
# [CV 1/5; 43/48] END max_depth=20, max_leaf_nodes=100;, score=0.623 total time=   0.0s
# [CV 2/5; 43/48] START max_depth=20, max_leaf_nodes=100..........................
# [CV 2/5; 43/48] END max_depth=20, max_leaf_nodes=100;, score=0.721 total time=   0.0s
# [CV 3/5; 43/48] START max_depth=20, max_leaf_nodes=100..........................
# [CV 3/5; 43/48] END max_depth=20, max_leaf_nodes=100;, score=0.852 total time=   0.0s
# [CV 4/5; 43/48] START max_depth=20, max_leaf_nodes=100..........................
# [CV 4/5; 43/48] END max_depth=20, max_leaf_nodes=100;, score=0.829 total time=   0.0s
# [CV 5/5; 43/48] START max_depth=20, max_leaf_nodes=100..........................
# [CV 5/5; 43/48] END max_depth=20, max_leaf_nodes=100;, score=0.456 total time=   0.0s
# [CV 1/5; 44/48] START max_depth=20, max_leaf_nodes=110..........................
# [CV 1/5; 44/48] END max_depth=20, max_leaf_nodes=110;, score=0.618 total time=   0.0s
# [CV 2/5; 44/48] START max_depth=20, max_leaf_nodes=110..........................
# [CV 2/5; 44/48] END max_depth=20, max_leaf_nodes=110;, score=0.765 total time=   0.0s
# [CV 3/5; 44/48] START max_depth=20, max_leaf_nodes=110..........................
# [CV 3/5; 44/48] END max_depth=20, max_leaf_nodes=110;, score=0.840 total time=   0.0s
# [CV 4/5; 44/48] START max_depth=20, max_leaf_nodes=110..........................
# [CV 4/5; 44/48] END max_depth=20, max_leaf_nodes=110;, score=0.739 total time=   0.0s
# [CV 5/5; 44/48] START max_depth=20, max_leaf_nodes=110..........................
# [CV 5/5; 44/48] END max_depth=20, max_leaf_nodes=110;, score=0.448 total time=   0.0s
# [CV 1/5; 45/48] START max_depth=20, max_leaf_nodes=120..........................
# [CV 1/5; 45/48] END max_depth=20, max_leaf_nodes=120;, score=0.637 total time=   0.0s
# [CV 2/5; 45/48] START max_depth=20, max_leaf_nodes=120..........................
# [CV 2/5; 45/48] END max_depth=20, max_leaf_nodes=120;, score=0.759 total time=   0.0s
# [CV 3/5; 45/48] START max_depth=20, max_leaf_nodes=120..........................
# [CV 3/5; 45/48] END max_depth=20, max_leaf_nodes=120;, score=0.849 total time=   0.0s
# [CV 4/5; 45/48] START max_depth=20, max_leaf_nodes=120..........................
# [CV 4/5; 45/48] END max_depth=20, max_leaf_nodes=120;, score=0.738 total time=   0.0s
# [CV 5/5; 45/48] START max_depth=20, max_leaf_nodes=120..........................
# [CV 5/5; 45/48] END max_depth=20, max_leaf_nodes=120;, score=0.455 total time=   0.0s
# [CV 1/5; 46/48] START max_depth=20, max_leaf_nodes=130..........................
# [CV 1/5; 46/48] END max_depth=20, max_leaf_nodes=130;, score=0.614 total time=   0.0s
# [CV 2/5; 46/48] START max_depth=20, max_leaf_nodes=130..........................
# [CV 2/5; 46/48] END max_depth=20, max_leaf_nodes=130;, score=0.757 total time=   0.0s
# [CV 3/5; 46/48] START max_depth=20, max_leaf_nodes=130..........................
# [CV 3/5; 46/48] END max_depth=20, max_leaf_nodes=130;, score=0.868 total time=   0.0s
# [CV 4/5; 46/48] START max_depth=20, max_leaf_nodes=130..........................
# [CV 4/5; 46/48] END max_depth=20, max_leaf_nodes=130;, score=0.762 total time=   0.0s
# [CV 5/5; 46/48] START max_depth=20, max_leaf_nodes=130..........................
# [CV 5/5; 46/48] END max_depth=20, max_leaf_nodes=130;, score=0.457 total time=   0.0s
# [CV 1/5; 47/48] START max_depth=20, max_leaf_nodes=140..........................
# [CV 1/5; 47/48] END max_depth=20, max_leaf_nodes=140;, score=0.612 total time=   0.0s
# [CV 2/5; 47/48] START max_depth=20, max_leaf_nodes=140..........................
# [CV 2/5; 47/48] END max_depth=20, max_leaf_nodes=140;, score=0.758 total time=   0.0s
# [CV 3/5; 47/48] START max_depth=20, max_leaf_nodes=140..........................
# [CV 3/5; 47/48] END max_depth=20, max_leaf_nodes=140;, score=0.864 total time=   0.0s
# [CV 4/5; 47/48] START max_depth=20, max_leaf_nodes=140..........................
# [CV 4/5; 47/48] END max_depth=20, max_leaf_nodes=140;, score=0.726 total time=   0.0s
# [CV 5/5; 47/48] START max_depth=20, max_leaf_nodes=140..........................
# [CV 5/5; 47/48] END max_depth=20, max_leaf_nodes=140;, score=0.485 total time=   0.0s
# [CV 1/5; 48/48] START max_depth=20, max_leaf_nodes=150..........................
# [CV 1/5; 48/48] END max_depth=20, max_leaf_nodes=150;, score=0.711 total time=   0.0s
# [CV 2/5; 48/48] START max_depth=20, max_leaf_nodes=150..........................
# [CV 2/5; 48/48] END max_depth=20, max_leaf_nodes=150;, score=0.729 total time=   0.0s
# [CV 3/5; 48/48] START max_depth=20, max_leaf_nodes=150..........................
# [CV 3/5; 48/48] END max_depth=20, max_leaf_nodes=150;, score=0.860 total time=   0.0s
# [CV 4/5; 48/48] START max_depth=20, max_leaf_nodes=150..........................
# [CV 4/5; 48/48] END max_depth=20, max_leaf_nodes=150;, score=0.792 total time=   0.0s
# [CV 5/5; 48/48] START max_depth=20, max_leaf_nodes=150..........................
# [CV 5/5; 48/48] END max_depth=20, max_leaf_nodes=150;, score=0.453 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [13, 14, 15, 16, 17, 18, 19, 20],
#                          'max_leaf_nodes': [100, 110, 120, 130, 140, 150]},
#              verbose=10)

# %%
model.best_params_
# Out:
# {'max_depth': 18, 'max_leaf_nodes': 140}

# %%
best_model = model.best_estimator_

pred = best_model.predict(X_test_norm)

print(f"MAE: {mean_absolute_error(pred, y_test): .2f}")
print(f"RMSE: {mean_squared_error(pred, y_test, squared=False): .2f}")
print(f"R2 score:  {best_model.score(X_test_norm, y_test): .2f}")
# Out:
# MAE:  2.63
# RMSE:  3.42
# R2 score:   0.82
# C:\Users\ivanj\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
import joblib

# %%
features.describe()
# Out:
#             INDUS         NOX          RM         AGE         DIS         TAX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    11.083992    0.554695    6.284634   68.518519    3.795043  408.237154
# std      6.699165    0.115878    0.702617   27.439466    2.105710  168.537116
# min      0.460000    0.385000    3.561000    2.900000    1.129600  187.000000
# 25%      5.190000    0.449000    5.885500   45.925000    2.100175  279.000000
# 50%      9.900000    0.538000    6.208500   74.450000    3.207450  330.000000
# 75%     18.100000    0.624000    6.623500   93.575000    5.188425  666.000000
# max     27.740000    0.871000    8.780000  100.000000   12.126500  711.000000
#
#           PTRATIO       LSTAT
# count  506.000000  506.000000
# mean    18.455534   12.715432
# std      2.164946    7.012739
# min     12.600000    1.730000
# 25%     17.400000    7.230000
# 50%     19.050000   11.995000
# 75%     20.200000   16.570000
# max     22.000000   37.970000

# %%
filename = 'finalized_model.sav'
joblib.dump(forest, filename)
# Out:
# ['finalized_model.sav']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.4.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.611874   10.768775   11.083992    0.067194    0.554695    6.284634
# std      8.545770   23.025124    6.699165    0.250605    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.611874    0.000000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.439466    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.925000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     74.450000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.575000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.715432   22.532806
# std      7.012739    9.197104
# min      1.730000    5.000000
# 25%      7.230000   17.025000
# 50%     11.995000   21.200000
# 75%     16.570000   25.000000
# max     37.970000   50.000000

# %%
# Assuming `X_train` is your training data
scaler = MinMaxScaler()
scaler.fit(X_train)

# Save the fitted scaler
joblib.dump(scaler, "scaler.sav")
# Out:
# ['scaler.sav']

# %%
forest.feature_importances_
# Out:
# array([0.00769988, 0.04545186, 0.49295077, 0.0919237 , 0.02342881,
#        0.0287257 , 0.30981928])
